# %%
from pytsp.util.distances import get_roundtrip
import numpy as np

# %%
from pytsp import DataGenerator,Routing
from pytsp.util.plot import Mapplot

# %%
dg = DataGenerator()
# Out:
# Index(['longitude', 'latitude', 'id', 'address'], dtype='object')
# 6443
# 100%|██████████| 10/10 [00:00<00:00, 402.07it/s]

# %%
r = Routing(dg.distances)

# %%
r.run(verbose=False)
# Out:
# Baseline fitness: 15,199,457 meters
# Gen 1 fitness: 10,555,671 meters
# Gen 2 fitness: 10,047,550 meters
# Gen 3 fitness: 10,000,844 meters
# Gen 4 fitness: 9,972,450 meters
# Gen 5 fitness: 9,768,156 meters
# Gen 6 fitness: 9,758,865 meters
# Gen 7 fitness: 9,758,865 meters
# Gen 8 fitness: 9,758,865 meters
# Gen 9 fitness: 9,758,865 meters
# Gen 10 fitness: 9,758,865 meters

# %%
route = r.fittest_individual

# %%
coordinates = dg.get_selected_cities_coordinates()

# %%
coordinates = dg.all_cities["coordinates"]

# %%
Mapplot.plot_map(coordinates=coordinates)
# Out:
# <iframe src="about:blank" width="400" height="400"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20sr
# ...

# %%
np.vstack(coordinates[:,:]).astype(float)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 np.vstack(coordinates[:,:]).astype(float)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
get_roundtrip(route,coordinates)
# Out:
# array([[  27.3373  ,  -82.54268 ],
#        [  39.851097,  -74.79658 ],
#        [  40.3118  ,  -74.5238  ],
#        [  42.33527 ,  -71.60416 ],
#        [  41.50499 ,  -81.61003 ],
#        [  39.047943,  -94.35484 ],
#        [  32.679   , -115.49891 ],
#        [  33.74263 , -116.3039  ],
#        [  33.8291  , -117.5253  ],
#        [  34.57984 , -118.12546 ],
#        [  27.3373  ,  -82.54268 ]], dtype=float32)
